# %%
import os

# %%
print(os.getcwd())
# Out:
# c:\Users\yashs\OneDrive\Desktop\Work codes\Progati\SOQ Script refactoring\Step 4 refactoring

# %%
os.path.exists('my_first_log.txt')
# Out:
# False

# %%
os.chdir('..')

# %%
os.getcwd()
# Out:
# 'c:\\Users\\yashs\\OneDrive\\Desktop\\Work codes\\Progati'
